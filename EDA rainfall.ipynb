# %%
import pandas as pd
df=pd.read_csv("rainfall.csv")
df
# Out:
#         num  altitude  sep  oct  nov  dec  jan  feb  mar  apr  may  \
# 0    110050        30  1.2   33   90  117  135  102   61   20  6.7
# 1    110351        35  2.3   34   86  121  144  106   62   23  4.5
# 2    110502        20  2.7   29   89  131  158  109   62   24  3.8
# 3    111001        10  2.9   32   91  137  152  113   61   21  4.8
# 4    111650        25  1.0   27   78  128  136  108   59   21  4.7
# ..      ...       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 164  321850      -220  0.2   13   33   53   64   56   35   11  4.7
# 165  330370      -375  0.1    6   10   20   22   19   11    6  1.3
# 166  337000      -390  0.0    5    3   10    7    7    7    3  0.5
# 167  345005        80  0.4    2    2    6    5    4    5    2  0.4
# 168  347702        11  0.0    4    2    5    4    3    3    2  1.0
#
#                   name        x_utm        y_utm
# 0    Kfar Rosh Hanikra  696533.0929  3660837.106
# 1                 Saar  697119.0761  3656748.194
# 2                Evron  696509.3390  3652434.139
# 3          Kfar Masrik  696541.6760  3641331.565
# 4        Kfar Hamakabi  697875.2885  3630156.099
# ..                 ...          ...          ...
# 164          Tirat Zvi  737522.4082  3590062.317
# 165              Kalya  733547.7554  3515345.019
# 166               Sdom  728245.6354  3435502.691
# 167            Yotveta  700626.2988  3307818.515
# 168              Eilat  689139.3140  3270290.211
#
# [169 rows x 14 columns]

# %%
df=pd.read_csv("rainfall.csv")
df.describe()
# Out:
#                 num    altitude         sep         oct         nov  \
# count  1.690000e+02  169.000000  169.000000  169.000000  169.000000
# mean   2.456413e+05  169.911243    1.025444   21.532544   64.852071
# std    3.102560e+05  258.583316    0.830234    8.226001   24.007849
# min    1.100500e+05 -390.000000    0.000000    2.000000    2.000000
# 25%    1.382800e+05   30.000000    0.400000   16.000000   51.000000
# 50%    2.139010e+05   95.000000    0.900000   21.000000   68.000000
# 75%    2.474120e+05  255.000000    1.400000   28.000000   82.000000
# max    2.496029e+06  955.000000    3.700000   40.000000  122.000000
#
#               dec         jan         feb         mar         apr         may  \
# count  169.000000  169.000000  169.000000  169.000000  169.000000  169.000000
# mean   105.798817  123.053254  103.130178   58.366864   16.769231    3.968639
# std     36.891343   41.072709   35.221167   20.060809    7.111359    2.023557
# min      5.000000    4.000000    3.000000    3.000000    2.000000    0.400000
# 25%     85.000000  102.000000   89.000000   49.000000   13.000000    2.500000
# 50%    113.000000  131.000000  106.000000   59.000000   16.000000    4.000000
# 75%    130.000000  146.000000  123.000000   68.000000   20.000000    5.100000
# max    202.000000  238.000000  196.000000  115.000000   40.000000   12.200000
#
#                x_utm         y_utm
# count     169.000000  1.690000e+02
# mean   699377.463367  3.572778e+06
# std     30980.405658  7.485351e+04
# min    629301.443000  3.270290e+06
# 25%    676015.026400  3.518277e+06
# 50%    697119.076100  3.599022e+06
# 75%    728581.831500  3.625696e+06
# max    761589.197700  3.681163e+06

# %%
df=pd.read_csv("rainfall.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   num       169 non-null    int64
#  1   altitude  169 non-null    int64
#  2   sep       169 non-null    float64
#  3   oct       169 non-null    int64
#  4   nov       169 non-null    int64
#  5   dec       169 non-null    int64
#  6   jan       169 non-null    int64
#  7   feb       169 non-null    int64
#  8   mar       169 non-null    int64
#  9   apr       169 non-null    int64
#  10  may       169 non-null    float64
#  11  name      169 non-null    object
#  12  x_utm     169 non-null    float64
#  13  y_utm     169 non-null    float64
# dtypes: float64(4), int64(9), object(1)
# memory usage: 18.6+ KB

# %%
df=pd.read_csv("rainfall.csv")
df.isnull().sum()
# Out:
# num         0
# altitude    0
# sep         0
# oct         0
# nov         0
# dec         0
# jan         0
# feb         0
# mar         0
# apr         0
# may         0
# name        0
# x_utm       0
# y_utm       0
# dtype: int64

# %%
df=pd.read_csv("rainfall.csv")
df.columns
# Out:
# Index(['num', 'altitude', 'sep', 'oct', 'nov', 'dec', 'jan', 'feb', 'mar',
#        'apr', 'may', 'name', 'x_utm', 'y_utm'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='nov',data=df)
plt.title("November Data ")
plt.show()

# %%
print(df['name'].value_counts())
# Out:
# Kfar Rosh Hanikra    1
# Elkana               1
# Izrael               1
# Kfar Yehezkel        1
# En Harod Meuhad      1
#                     ..
# Beeri                1
# Nirim                1
# Nir Oz               1
# Magen                1
# Eilat                1
# Name: name, Length: 169, dtype: int64

# %%
sns.displot(df.altitude)
plt.title("Altitude")
plt.show()

# %%
plt.figure(figsize=(20,10))
tags=df['altitude'].value_counts(100)
tags.plot(kind='pie',autopct='%1.1f%%',label='')
plt.show()
